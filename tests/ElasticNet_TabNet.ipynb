# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# Load data
df = pd.read_csv("modified.csv")
X = df.drop(columns=["Country", "Gender", "Year.1", "Life expectancy", "Year"])
y = df["Life expectancy"]

# %%
# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Train ElasticNet model
model = ElasticNet(alpha=0.1, l1_ratio=0.5, random_state=42)
model.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=0.1, random_state=42)

# %%
# Predict and evaluate
y_pred = model.predict(X_test)
print("ElasticNet Results:")
print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R²:", r2_score(y_test, y_pred))
# Out:
# ElasticNet Results:
# MAE: 0.24924955092462606
# MSE: 0.10467974642061481
# RMSE: 0.32354249554056236
# R²: 0.8931584236206881

# %%
# First install the library if not already installed
# %pip install pytorch-tabnet
# Out:
# Collecting pytorch-tabnet
#   Downloading pytorch_tabnet-4.1.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\urvi\anaconda3\lib\site-packages (from pytorch-tabnet) (1.26.4)
# Requirement already satisfied: scikit_learn>0.21 in c:\users\urvi\anaconda3\lib\site-packages (from pytorch-tabnet) (1.4.2)
# Requirement already satisfied: scipy>1.4 in c:\users\urvi\anaconda3\lib\site-packages (from pytorch-tabnet) (1.13.1)
# Requirement already satisfied: torch>=1.3 in c:\users\urvi\anaconda3\lib\site-packages (from pytorch-tabnet) (2.6.0+cpu)
# Requirement already satisfied: tqdm>=4.36 in c:\users\urvi\anaconda3\lib\site-packages (from pytorch-tabnet) (4.66.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\urvi\anaconda3\lib\site-packages (from scikit_learn>0.21->pytorch-tabnet) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\urvi\anaconda3\lib\site-packages (from scikit_learn>0.21->pytorch-tabnet) (2.2.0)
# Requirement already satisfied: filelock in c:\users\urvi\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\urvi\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (4.12.2)
# Requirement already satisfied: networkx in c:\users\urvi\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\urvi\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\urvi\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (2024.3.1)
# Requirement already satisfied: setuptools in c:\users\urvi\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (69.5.1)
# Requirement already satisfied: sympy==1.13.1 in c:\users\urvi\anaconda3\lib\site-packages (from torch>=1.3->pytorch-tabnet) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\urvi\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.3->pytorch-tabnet) (1.3.0)
# Requirement already satisfied: colorama in c:\users\urvi\anaconda3\lib\site-packages (from tqdm>=4.36->pytorch-tabnet) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\urvi\anaconda3\lib\site-packages (from jinja2->torch>=1.3->pytorch-tabnet) (2.1.3)
# Downloading pytorch_tabnet-4.1.0-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/44.5 kB ? eta -:--:--
#    ------------------ --------------------- 20.5/44.5 kB 640.0 kB/s eta 0:00:01
#    ---------------------------------------- 44.5/44.5 kB 728.5 kB/s eta 0:00:00
# Installing collected packages: pytorch-tabnet
# Successfully installed pytorch-tabnet-4.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from pytorch_tabnet.tab_model import TabNetRegressor
import torch

# Load data
df = pd.read_csv("modified.csv")
X = df.drop(columns=["Country", "Gender", "Year.1", "Life expectancy", "Year"]).values
y = df["Life expectancy"].values.reshape(-1, 1)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize model
tabnet = TabNetRegressor(optimizer_fn=torch.optim.Adam,
                         optimizer_params=dict(lr=2e-2),
                         verbose=10,
                         seed=42)

# Fit model
tabnet.fit(X_train=X_train, y_train=y_train,
           eval_set=[(X_test, y_test)],
           eval_metric=['rmse'])

# Predict and evaluate
y_pred = tabnet.predict(X_test)
print("TabNet Results:")
print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R²:", r2_score(y_test, y_pred))
# Out:
# c:\Users\Urvi\anaconda3\Lib\site-packages\pytorch_tabnet\abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 6.55419 | val_0_rmse: 0.90221 |  0:00:00s
# epoch 10 | loss: 0.11202 | val_0_rmse: 0.29702 |  0:00:02s
# epoch 20 | loss: 0.08351 | val_0_rmse: 0.2661  |  0:00:05s
# epoch 30 | loss: 0.06956 | val_0_rmse: 0.23824 |  0:00:07s
# epoch 40 | loss: 0.05932 | val_0_rmse: 0.22171 |  0:00:09s
# epoch 50 | loss: 0.05475 | val_0_rmse: 0.21628 |  0:00:11s
# epoch 60 | loss: 0.05273 | val_0_rmse: 0.20838 |  0:00:14s
# epoch 70 | loss: 0.05172 | val_0_rmse: 0.21064 |  0:00:17s
# epoch 80 | loss: 0.04893 | val_0_rmse: 0.20668 |  0:00:19s
# epoch 90 | loss: 0.04775 | val_0_rmse: 0.20024 |  0:00:22s
# Stop training because you reached max_epochs = 100 with best_epoch = 97 and best_val_0_rmse = 0.19372
# TabNet Results:
# MAE: 0.14168409583017375
# MSE: 0.03752631566847984
# RMSE: 0.193717102157966
# R²: 0.9616986966550534
# c:\Users\Urvi\anaconda3\Lib\site-packages\pytorch_tabnet\callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
